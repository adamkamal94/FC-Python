# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#This next line makes our charts show up in the notebook
# %matplotlib inline

#This next line makes our charts show up in the notebook
# %matplotlib inline

table = pd.read_csv("C:/Users/Adam/Downloads/1617table.csv")
table.head()
# Out:
#    Pos               Team  Pld   W   D  L  GF  GA  GD  Pts
# 0    1            Chelsea   38  30   3  5  85  33  52   93
# 1    2  Tottenham Hotspur   38  26   8  4  86  26  60   86
# 2    3    Manchester City   38  23   9  6  80  39  41   78
# 3    4          Liverpool   38  22  10  6  78  42  36   76
# 4    5            Arsenal   38  23   6  9  77  44  33   75

# %%
plt.bar(x=np.arange(1,21) ,height=table['Pts'])
# Out:
# <BarContainer object of 20 artists>

# %%
#Create our bar chart as before
plt.bar(x=np.arange(1,21) ,height=table['Pts'])

#Give it a title
plt.title("Premier League 16/17")

#Give the x axis some labels across the tick marks.
#Arguement one is the position for each label
#Arugement two is the label values and the final one is to rotate our labels
plt.xticks(np.arange(1,21), table['Team'], rotation=90)

#Give the x and y axes a title
plt.xlabel("Team")
plt.ylabel("Points")

#Finally, show me our new plot
plt.show()

# %%
#Create an array of equal length to our bars
#Each value is the hex code for the team's colours, in order of our chart
teamColours = ['#034694','#001C58','#5CBFEB','#D00027',
              '#EF0107','#DA020E','#274488','#ED1A3B',
               '#000000','#091453','#60223B','#0053A0',
               '#E03A3E','#1B458F','#000000','#53162f',
               '#FBEE23','#EF6610','#C92520','#BA1F1A']

#Add a new arguement, color, to our 'plt.bar()' method
#This arguement passes our teamColours array
plt.bar(x=np.arange(1,21) ,height=table['Pts'],color = teamColours)

#Label bars, axes and the chart as before
plt.title("Premier League 16/17")
plt.xticks(np.arange(1,21), table['Team'], rotation=90)
plt.xlabel("Team")
plt.ylabel("Points")
plt.show()

# %%
#This next line makes our charts show up in the notebook
# %matplotlib inline

table = pd.read_csv("C:/Users/Adam/Downloads/1617table.csv")
table.head()
# Out:
#    Pos               Team  Pld   W   D  L  GF  GA  GD  Pts
# 0    1            Chelsea   38  30   3  5  85  33  52   93
# 1    2  Tottenham Hotspur   38  26   8  4  86  26  60   86
# 2    3    Manchester City   38  23   9  6  80  39  41   78
# 3    4          Liverpool   38  22  10  6  78  42  36   76
# 4    5            Arsenal   38  23   6  9  77  44  33   75

# %%
plt.hlines(y=np.arange(1,21),xmin=0,xmax=table['Pts'])

# %%
plt.hlines(y=np.arange(1,21),xmin=0,xmax=table['Pts'],color="skyblue")
plt.plot(table['Pts'], np.arange(1,21), "o")
plt.yticks(np.arange(1,21), table['Team'])
plt.show()

# %%
#Create an array of equal length to our bars
#Each value is the hex code for the team's colours, in order of our chart
teamColours = ['#034694','#001C58','#5CBFEB','#D00027',
              '#EF0107','#DA020E','#274488','#ED1A3B',
               '#000000','#091453','#60223B','#0053A0',
               '#E03A3E','#1B458F','#000000','#53162f',
               '#FBEE23','#EF6610','#C92520','#BA1F1A']

plt.hlines(y=np.arange(1,21),xmin=0,xmax=table['Pts'],color=teamColours)
plt.plot(table['Pts'], np.arange(1,21), "o")
plt.yticks(np.arange(1,21), table['Team'])

plt.ylabel("Team")
plt.xlabel("Points")

plt.title("Premier League 16/17")

plt.show()

# %%
table = pd.read_csv("C:/Users/Adam/Downloads/1415table.csv")
table.head()
# Out:
#    Pos               Team  Pld   W   D   L  GF  GA  GD  Pts
# 0    1           Chelsea    38  26   9   3  73  32  41   87
# 1    2    Manchester City   38  24   7   7  83  38  45   79
# 2    3            Arsenal   38  22   9   7  71  36  35   75
# 3    4  Manchester United   38  20  10   8  62  37  25   70
# 4    5  Tottenham Hotspur   38  19   7  12  58  53   5   64

# %%
plt.plot(table['GF'],table['GA'],"o")

# %%
#Create plot area
fig, ax=plt.subplots()

#Set plot size
fig.set_size_inches(7,5)

#Plot chart as above, but change the plot type from 'o' to '*'
plt.plot(table['GF'],table['GA'],"*")

#Add labels to chart area
ax.set_title("Goals for & Against")
ax.set_xlabel("Goals For")
ax.set_ylabel("Goals Against")

#Display the chart
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

plt.plot(table['GF'],table['GA'],"o")
plt.plot([table['GF'].mean(),table['GF'].mean()],[90,20],'k-', linestyle = ":", lw=1)
plt.plot([20,90],[table['GA'].mean(),table['GA'].mean()],'k-', linestyle = ":", lw=1)

ax.set_title("Goals For & Against")
ax.set_xlabel("Goals For")
ax.set_ylabel("Goals Against")

plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

plt.plot(table['GF'],table['GA'],"o")
plt.plot([table['GF'].mean(),table['GF'].mean()],[90,20],'k-', linestyle = ":", lw=1)
plt.plot([20,90],[table['GA'].mean(),table['GA'].mean()],'k-', linestyle = ":", lw=1)

ax.set_title("Goals For & Against")
ax.set_xlabel("Goals For")
ax.set_ylabel("Goals Against")

ax.text(18,90,"Poor attack, poor defense",color="red",size="8")
ax.text(67,20,"Strong attack, strong defense",color="red",size="8")

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import squarify

# %%
data = pd.read_csv("C:/Users/Adam/Desktop/Chelseastats.csv", encoding="ISO-8859-1")
data.head()
# Out:
#               Player Pos  GP  GS    MP   G  A  SpG   PS%  YC  RC
# 0      Tammy Abraham   F  25  23  1944  13  3  2.9  67.4   2   0
# 1        Mason Mount   M  29  25  2302   6  4  2.3  85.1   3   0
# 2            Willian   M  28  21  1930   5  5  1.9  83.0   3   0
# 3  Christian Pulisic   M  16  12  1076   5  2  2.5  80.2   0   0
# 4      Marcos Alonso   D  11   9   860   4  2  1.6  81.9   3   0

# %%
#New dataframe, containing only players with more than 0 goals.
dataGoals = data[data["G"]>0]

#Utilise matplotlib to scale our goal numbers between the min and max, then assign this scale to our values.
norm = matplotlib.colors.Normalize(vmin=min(dataGoals.G), vmax=max(dataGoals.G))
colors = [matplotlib.cm.Blues(norm(value)) for value in dataGoals.G]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 4.5)

#Use squarify to plot our data, label it and add colours. We add an aplha layer to ensure black labels show through
squarify.plot(label=dataGoals.Player,sizes=dataGoals.G, color = colors, alpha=.6)
plt.title("Chelsea Goals",fontsize=23,fontweight='bold')

#Remove our axes and display the plot
plt.axis('off')
plt.show()

# %%
dataAssists = data[data["A"]>0]

#Utilise matplotlib to scale our goal numbers between the min and max, then assign this scale to our values.
norm = matplotlib.colors.Normalize(vmin=min(dataAssists.A), vmax=max(dataAssists.A))
colors = [matplotlib.cm.Blues(norm(value)) for value in dataAssists.A]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 4.5)

#Use squarify to plot our data, label it and add colours. We add an aplha layer to ensure black labels show through
squarify.plot(label=dataAssists.Player,sizes=dataAssists.A, color = colors, alpha=.6)
plt.title("Chelsea Assists",fontsize=23,fontweight='bold')

#Remove our axes and display the plot
plt.axis('off')
plt.show()

# %%
from __future__ import unicode_literals
import joypy
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm
# %matplotlib inline

df = pd.read_csv("C:/Users/Adam/Downloads/top25transfers.csv")

df.head()
# Out:
#                 Name  Value  Year
# 0        David Platt   8.25  1991
# 1  Robert Prosinecki   8.00  1991
# 2      Thomas Häßler   7.70  1991
# 3      Jürgen Kohler   7.50  1991
# 4        Thomas Doll   7.50  1991

# %%
fig, axes = joypy.joyplot(df, by="Year", column="Value",figsize=(5,8))
plt.show()

# %%
fig, axes = joypy.joyplot(df[df.Name != 'Neymar'], by="Year", column="Value",figsize=(5,8),
             linewidth=0.05,overlap=3,colormap=cm.summer_r,x_range=[0,110])

plt.text(40, 0.8, "Top 25 transfer values (€m) \n 1991-2019",fontsize=12)

plt.show()

# %%
#Import our data and assign it to 'data'
data = pd.read_csv("C:/Users/Adam/Downloads/E0.csv")

#Show the top of the dataframe
data.head()
# Out:
#   Div      Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 0  E0  15/08/09  Aston Villa       Wigan     0     2   A     0     1   A  ...
# 1  E0  15/08/09    Blackburn    Man City     0     2   A     0     1   A  ...
# 2  E0  15/08/09       Bolton  Sunderland     0     1   A     0     1   A  ...
# 3  E0  15/08/09      Chelsea        Hull     2     1   H     1     1   D  ...
# 4  E0  15/08/09      Everton     Arsenal     1     6   A     0     3   A  ...
#
#   BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  \
# 0     2.04      1.92      1.91      1.81    21    0.0     1.28     1.22
# 1     2.15      2.04      1.78      1.71    24    0.0     2.58     2.38
# 2     2.25      2.12      1.70      1.66    23    0.0     1.68     1.61
# 3     1.67      1.58      2.44      2.26    22    0.0     1.03     1.02
# 4     2.20      2.06      1.77      1.70    24    0.0     2.27     2.20
#
#    BbMxAHA  BbAvAHA
# 0     4.40     3.99
# 1     1.60     1.54
# ...

# %%
#Create a list of unique teams from the home team column
Teams = data.HomeTeam.unique()

#Create a dictionary called TeamLists. There will be an entry for each team with the list [0]
TeamLists = {Team : [0] for Team in Teams}

# %%
Teams = data.HomeTeam.unique()
TeamLists = {Team : [0] for Team in Teams}

for row in data.itertuples():
    Home = row.HomeTeam
    Away = row.AwayTeam
    
    if row.FTHG > row.FTAG:
        TeamLists[Home].append(TeamLists[Home][-1]+3)
        TeamLists[Away].append(TeamLists[Away][-1]+0)
    elif row.FTHG < row.FTAG:
        TeamLists[Home].append(TeamLists[Home][-1]+0)
        TeamLists[Away].append(TeamLists[Away][-1]+3)
    else:
        TeamLists[Home].append(TeamLists[Home][-1]+1)
        TeamLists[Away].append(TeamLists[Away][-1]+1)

# %%
TeamLists["Chelsea"]
# Out:
# [0,
#  3,
#  6,
#  9,
#  12,
#  15,
#  18,
#  18,
#  21,
#  21,
#  24,
#  27,
#  30,
#  33,
#  36,
#  36,
#  37,
#  40,
#  41,
#  42,
#  45,
#  48,
#  51,
#  54,
#  55,
#  58,
#  58,
#  61,
#  61,
#  64,
#  65,
#  68,
#  71,
#  74,
#  77,
#  77,
#  80,
#  83,
#  86]

# %%
Matchday = list(range(0,39))

# %%
#Create a line plot with matchday and teamlist figures for two teams
plt.plot(Matchday, TeamLists["Chelsea"])
plt.plot(Matchday, TeamLists["Man United"])

# %%
#Create the bare bones of what will be our visualisation
fig, ax = plt.subplots()

#Add our data as before, but setting colours and widths of lines
plt.plot(Matchday, TeamLists["Chelsea"], color = "#4169e1", linewidth=2)
plt.plot(Matchday, TeamLists["Man United"], color = "#FF0000", linewidth=2)

#Give the axes and plot a title each
plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Chelsea v Man United Running Points')

#Add a faint grey grid
plt.grid()
ax.xaxis.grid(color = "#F8F8F8")
ax.yaxis.grid(color = "#F9F9F9")

#Remove the margins between our lines and the axes
plt.margins(x=0,y=0)

#Remove the spines of the chart on the top and right sides
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
from scipy.spatial import ConvexHull

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# %matplotlib inline

# %%
defdata = pd.read_csv("C:/Users/Adam/Downloads/def_table.csv")
defdata.head()
# Out:
#    Player    Team  Minute    X   Y  Outcome
# 0    5197  Team B       1    6  24        1
# 1    5197  Team B      34   12  28        1
# 2    5193  Team A       6   17   6        1
# 3    5193  Team A       8  105  25        1
# 4    5193  Team A      51   80  30        1

# %%
player5184 = defdata.loc[(defdata['Player'] == 5184)]

player5184.head()
# Out:
#     Player    Team  Minute   X   Y  Outcome
# 16    5184  Team B      10  65  76        1
# 17    5184  Team B      33   4  59        1
# 18    5184  Team B      49  21  61        1
# 19    5184  Team B      54  43  41        1

# %%
defpoints = player5184[['X', 'Y']].values

defpoints
# Out:
# array([[65, 76],
#        [ 4, 59],
#        [21, 61],
#        [43, 41]], dtype=int64)

# %%
#Create a convex hull object and assign it to the variable hull
hull = ConvexHull(player5184[['X','Y']])

#Display hull
hull

# %%
#Plot the X & Y location with dots
plt.plot(player5184.X,player5184.Y, 'o')

# %%
#Plot the X & Y location with dots
plt.plot(player5184.X,player5184.Y, 'o')

#Loop through each of the hull's simplices
for simplex in hull.simplices:
    #Draw a black line between each
    plt.plot(defpoints[simplex, 0], defpoints[simplex, 1], 'k-')
    
#Fill the area within the lines that we have drawn
plt.fill(defpoints[hull.vertices,0], defpoints[hull.vertices,1], 'k', alpha=0.3)

# %%
TeamB = defdata.loc[(defdata.Team == "Team B")]
TeamB.head()
# Out:
#    Player    Team  Minute   X   Y  Outcome
# 0    5197  Team B       1   6  24        1
# 1    5197  Team B      34  12  28        1
# 5    5191  Team B       2   2  66        1
# 6    5191  Team B      53  57  58        1
# 7    5191  Team B      87  49  53        1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# %matplotlib inline

data = pd.read_csv("C:/Users/Adam/Downloads/zidanepasses.csv")

data.head()
# Out:
#          HALF  TIME EVENT  PLAYER    TEAM  XSTART  YSTART  XEND  YEND
# 0  First Half    14  Pass  Zidane  France      34      24     4    20
# 1  First Half    15  Pass  Zidane  France      41      46   117    60
# 2  First Half    15  Pass  Zidane  France       8      28   113    19
# 3  First Half    17  Pass  Zidane  France       1       3    69    73
# 4  First Half    18  Pass  Zidane  France      10      81    91     3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# %matplotlib inline

data = pd.read_csv("C:/Users/Adam/Downloads/zidanepasses.csv")

data.head()
# Out:
#          HALF  TIME EVENT  PLAYER    TEAM  XSTART  YSTART  XEND  YEND
# 0  First Half    14  Pass  Zidane  France      34      24     4    20
# 1  First Half    15  Pass  Zidane  France      41      46   117    60
# 2  First Half    15  Pass  Zidane  France       8      28   113    19
# 3  First Half    17  Pass  Zidane  France       1       3    69    73
# 4  First Half    18  Pass  Zidane  France      10      81    91     3

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

for i in range(len(data)):
    plt.plot([int(data["XSTART"][i]),int(data["XEND"][i])],
             [int(data["YSTART"][i]),int(data["YEND"][i])], 
             color="blue")
    
plt.show()

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

for i in range(len(data)):
    plt.plot([int(data["XSTART"][i]),int(data["XEND"][i])],[int(data["YSTART"][i]),int(data["YEND"][i])], color="blue")
    plt.plot(int(data["XSTART"][i]),int(data["YSTART"][i]),"o", color="green")

#Display Pitch
plt.show()
